# %% [markdown]
# <a href="https://colab.research.google.com/github/ConstantRietsch/JBC_Trading/blob/main/Stock_Screener.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
#https://towardsdatascience.com/making-a-stock-screener-with-python-4f591b198261
# !pip install yahoo_fin
# !pip install yfinance

from pandas_datareader import data as pdr
from yahoo_fin import stock_info as si
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import datetime
import time
yf.pdr_override()

# Variables
tickers = si.tickers_sp500()
tickers = [item.replace(".", "-") for item in tickers] # Yahoo Finance uses dashes instead of dots
index_name = '^GSPC' # S&P 500
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()
exportList = pd.DataFrame(columns=['Stock', "RS_Rating", "50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High"])
returns_multiples = []

# Index Returns
index_df = pdr.get_data_yahoo(index_name, start_date, end_date)
index_df['Percent Change'] = index_df['Adj Close'].pct_change()
index_return = (index_df['Percent Change'] + 1).cumprod()[-1]

# Find top 30% performing stocks (relative to the S&P 500)
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    df = pdr.get_data_yahoo(ticker, start_date, end_date)
    df.to_csv(f'{ticker}.csv')

    # Calculating returns relative to the market (returns multiple)
    df['Percent Change'] = df['Adj Close'].pct_change()
    stock_return = (df['Percent Change'] + 1).cumprod()[-1]
    
    returns_multiple = round((stock_return / index_return), 2)
    returns_multiples.extend([returns_multiple])
    
    print (f'Ticker: {ticker}; Returns Multiple against S&P 500: {returns_multiple}\n')
    time.sleep(1)

# Creating dataframe of only top 30%
rs_df = pd.DataFrame(list(zip(tickers, returns_multiples)), columns=['Ticker', 'Returns_multiple'])
rs_df['RS_Rating'] = rs_df.Returns_multiple.rank(pct=True) * 100
rs_df = rs_df[rs_df.RS_Rating >= rs_df.RS_Rating.quantile(.70)]

# Checking Minervini conditions of top 30% of stocks in given list
rs_stocks = rs_df['Ticker']
for stock in rs_stocks:    
    try:
        df = pd.read_csv(f'{stock}.csv', index_col=0)
        sma = [50, 150, 200]
        for x in sma:
            df["SMA_"+str(x)] = round(df['Adj Close'].rolling(window=x).mean(), 2)
        
        # Storing required values 
        currentClose = df["Adj Close"][-1]
        moving_average_50 = df["SMA_50"][-1]
        moving_average_150 = df["SMA_150"][-1]
        moving_average_200 = df["SMA_200"][-1]
        low_of_52week = round(min(df["Low"][-260:]), 2)
        high_of_52week = round(max(df["High"][-260:]), 2)
        RS_Rating = round(rs_df[rs_df['Ticker']==stock].RS_Rating.tolist()[0])
        
        try:
            moving_average_200_20 = df["SMA_200"][-20]
        except Exception:
            moving_average_200_20 = 0

        # Condition 1: Current Price > 150 SMA and > 200 SMA
        condition_1 = currentClose > moving_average_150 > moving_average_200
        
        # Condition 2: 150 SMA and > 200 SMA
        condition_2 = moving_average_150 > moving_average_200

        # Condition 3: 200 SMA trending up for at least 1 month
        condition_3 = moving_average_200 > moving_average_200_20
        
        # Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
        condition_4 = moving_average_50 > moving_average_150 > moving_average_200
           
        # Condition 5: Current Price > 50 SMA
        condition_5 = currentClose > moving_average_50
           
        # Condition 6: Current Price is at least 30% above 52 week low
        condition_6 = currentClose >= (1.3*low_of_52week)
           
        # Condition 7: Current Price is within 25% of 52 week high
        condition_7 = currentClose >= (.75*high_of_52week)
        
        # If all conditions above are true, add stock to exportList
        if(condition_1 and condition_2 and condition_3 and condition_4 and condition_5 and condition_6 and condition_7):
            exportList = exportList.append({'Stock': stock, "RS_Rating": RS_Rating ,"50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
            print (stock + " made the Minervini requirements")
    except Exception as e:
        print (e)
        print(f"Could not gather data on {stock}")

exportList = exportList.sort_values(by='RS_Rating', ascending=False)
print('\n', exportList)
writer = ExcelWriter("ScreenOutput.xlsx")
exportList.to_excel(writer, "Sheet1")
writer.save()
# Out:
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.6/dist-packages (0.8.6)
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/7a/e8/b9d7104d3a4bf39924799067592d9e59119fcfc900a425a12e80a3123ec8/yfinance-0.1.55.tar.gz
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Collecting lxml>=4.5.1
#   Downloading https://files.pythonhosted.org/packages/bd/78/56a7c88a57d0d14945472535d0df9fb4bbad7d34ede658ec7961635c790e/lxml-4.6.2-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 22.4MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=83cfaf51541929fafd398b1f542d2cb342059cb6837529b53dc5dc97ce8d2e48
#   Stored in directory: /root/.cache/pip/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# Installing collected packages: lxml, yfinance
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.6.2 yfinance-0.1.55
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Ticker: A; Returns Multiple against S&P 500: 1.27
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAL; Returns Multiple against S&P 500: 0.53
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAP; Returns Multiple against S&P 500: 1.03
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAPL; Returns Multiple against S&P 500: 1.47
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ABBV; Returns Multiple against S&P 500: 1.13
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ABC; Returns Multiple against S&P 500: 1.06
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ABMD; Returns Multiple against S&P 500: 1.43
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ABT; Returns Multiple against S&P 500: 1.17
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ACN; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ADBE; Returns Multiple against S&P 500: 1.15
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ADI; Returns Multiple against S&P 500: 1.15
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ADM; Returns Multiple against S&P 500: 1.02
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ADP; Returns Multiple against S&P 500: 0.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ADSK; Returns Multiple against S&P 500: 1.26
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AEE; Returns Multiple against S&P 500: 0.79
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AEP; Returns Multiple against S&P 500: 0.72
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AES; Returns Multiple against S&P 500: 1.14
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AFL; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AIG; Returns Multiple against S&P 500: 0.7
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AIZ; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AJG; Returns Multiple against S&P 500: 0.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AKAM; Returns Multiple against S&P 500: 1.0
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ALB; Returns Multiple against S&P 500: 1.57
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ALGN; Returns Multiple against S&P 500: 1.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ALK; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ALL; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ALLE; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ALXN; Returns Multiple against S&P 500: 1.29
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AMAT; Returns Multiple against S&P 500: 1.43
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AMCR; Returns Multiple against S&P 500: 0.92
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AMD; Returns Multiple against S&P 500: 1.54
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AME; Returns Multiple against S&P 500: 1.03
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AMGN; Returns Multiple against S&P 500: 0.91
#
# [*********************100%***********************]  1 of 1 completed
# Ticker:
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ETN; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ETR; Returns Multiple against S&P 500: 0.66
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ETSY; Returns Multiple against S&P 500: 3.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: EVRG; Returns Multiple against S&P 500: 0.69
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: EW; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: EXC; Returns Multiple against S&P 500: 0.81
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: EXPD; Returns Multiple against S&P 500: 1.08
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: EXPE; Returns Multiple against S&P 500: 1.1
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: EXR; Returns Multiple against S&P 500: 0.95
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: F; Returns Multiple against S&P 500: 1.19
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FANG; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FAST; Returns Multiple against S&P 500: 1.11
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FB; Returns Multiple against S&P 500: 1.09
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FBHS; Returns Multiple against S&P 500: 1.09
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FCX; Returns Multiple against S&P 500: 2.09
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FDX; Returns Multiple against S&P 500: 1.46
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FE; Returns Multiple against S&P 500: 0.57
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FFIV; Returns Multiple against S&P 500: 1.39
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FIS; Returns Multiple against S&P 500: 0.79
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FISV; Returns Multiple against S&P 500: 0.8
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FITB; Returns Multiple against S&P 500: 0.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FLIR; Returns Multiple against S&P 500: 0.89
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FLS; Returns Multiple against S&P 500: 0.67
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FLT; Returns Multiple against S&P 500: 0.69
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FMC; Returns Multiple against S&P 500: 0.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FOX; Returns Multiple against S&P 500: 0.71
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FOXA; Returns Multiple against S&P 500: 0.72
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FRC; Returns Multiple against S&P 500: 1.17
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FRT; Returns Multiple against S&P 500: 0.64
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FTI; Returns Multiple against S&P 500: 0.58
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FTNT; Returns Multiple against S&P 500: 1.12
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: FTV; Returns Multiple against S&P 500: 0.88
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GD; Returns Multiple against S&P 500: 0.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GE; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GILD; Returns Multiple against S&P 500: 0.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GIS; Returns Multiple against S&P 500: 0.98
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GL; Returns Multiple against S&P 500: 0.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GLW; Returns Multiple against S&P 500: 1.18
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GM; Returns Multiple against S&P 500: 1.38
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GOOG; Returns Multiple against S&P 500: 1.21
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GOOGL; Returns Multiple against S&P 500: 1.2
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GPC; Returns Multiple against S&P 500: 0.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GPN; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GPS; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GRMN; Returns Multiple against S&P 500: 1.08
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GS; Returns Multiple against S&P 500: 1.08
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GWW; Returns Multiple against S&P 500: 1.06
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HAL; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HAS; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HBAN; Returns Multiple against S&P 500: 0.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HBI; Returns Multiple against S&P 500: 0.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HCA; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HD; Returns Multiple against S&P 500: 1.03
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HES; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HFC; Returns Multiple against S&P 500: 0.63
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HIG; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HII; Returns Multiple against S&P 500: 0.53
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HLT; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HOLX; Returns Multiple against S&P 500: 1.34
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HON; Returns Multiple against S&P 500: 1.01
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HPE; Returns Multiple against S&P 500: 0.78
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HPQ; Returns Multiple against S&P 500: 1.06
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HRL; Returns Multiple against S&P 500: 0.92
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HSIC; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HST; Returns Multiple against S&P 500: 0.73
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HSY; Returns Multiple against S&P 500: 0.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HUM; Returns Multiple against S&P 500: 0.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HWM; Returns Multiple against S&P 500: 0.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IBM; Returns Multiple against S&P 500: 0.7
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ICE; Returns Multiple against S&P 500: 1.11
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IDXX; Returns Multiple against S&P 500: 1.52
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IEX; Returns Multiple against S&P 500: 0.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IFF; Returns Multiple against S&P 500: 0.79
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ILMN; Returns Multiple against S&P 500: 1.23
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: INCY; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: INFO; Returns Multiple against S&P 500: 0.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: INTC; Returns Multiple against S&P 500: 0.78
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: INTU; Returns Multiple against S&P 500: 1.16
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IP; Returns Multiple against S&P 500: 0.96
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IPG; Returns Multiple against S&P 500: 1.01
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IPGP; Returns Multiple against S&P 500: 1.43
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IQV; Returns Multiple against S&P 500: 0.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IR; Returns Multiple against S&P 500: 1.0
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IRM; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ISRG; Returns Multiple against S&P 500: 1.12
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IT; Returns Multiple against S&P 500: 0.91
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ITW; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IVZ; Returns Multiple against S&P 500: 1.1
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: J; Returns Multiple against S&P 500: 0.98
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JBHT; Returns Multiple against S&P 500: 1.11
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JCI; Returns Multiple against S&P 500: 1.14
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JKHY; Returns Multiple against S&P 500: 0.82
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JNJ; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JNPR; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JPM; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: K; Returns Multiple against S&P 500: 0.82
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KEY; Returns Multiple against S&P 500: 0.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KEYS; Returns Multiple against S&P 500: 1.26
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KHC; Returns Multiple against S&P 500: 1.03
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KIM; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KLAC; Returns Multiple against S&P 500: 1.51
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KMB; Returns Multiple against S&P 500: 0.81
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KMI; Returns Multiple against S&P 500: 0.61
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KMX; Returns Multiple against S&P 500: 1.12
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KO; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KR; Returns Multiple against S&P 500: 1.05
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KSU; Returns Multiple against S&P 500: 1.07
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: L; Returns Multiple against S&P 500: 0.78
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LB; Returns Multiple against S&P 500: 1.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LDOS; Returns Multiple against S&P 500: 0.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LEG; Returns Multiple against S&P 500: 0.83
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LEN; Returns Multiple against S&P 500: 1.11
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LH; Returns Multiple against S&P 500: 1.05
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LHX; Returns Multiple against S&P 500: 0.72
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LIN; Returns Multiple against S&P 500: 1.01
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LKQ; Returns Multiple against S&P 500: 0.98
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LLY; Returns Multiple against S&P 500: 1.21
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LMT; Returns Multiple against S&P 500: 0.68
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LNC; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LNT; Returns Multiple against S&P 500: 0.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LOW; Returns Multiple against S&P 500: 1.25
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LRCX; Returns Multiple against S&P 500: 1.41
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LUMN; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LUV; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LVS; Returns Multiple against S&P 500: 0.67
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LW; Returns Multiple against S&P 500: 0.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LYB; Returns Multiple against S&P 500: 1.0
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LYV; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MA; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MAA; Returns Multiple against S&P 500: 0.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MAR; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MAS; Returns Multiple against S&P 500: 0.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MCD; Returns Multiple against S&P 500: 0.88
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MCHP; Returns Multiple against S&P 500: 1.16
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MCK; Returns Multiple against S&P 500: 1.03
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MCO; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MDLZ; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MDT; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MET; Returns Multiple against S&P 500: 0.91
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MGM; Returns Multiple against S&P 500: 0.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MHK; Returns Multiple against S&P 500: 0.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MKC; Returns Multiple against S&P 500: 0.96
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MKTX; Returns Multiple against S&P 500: 1.42
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MLM; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MMC; Returns Multiple against S&P 500: 0.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MMM; Returns Multiple against S&P 500: 0.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MNST; Returns Multiple against S&P 500: 1.14
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MO; Returns Multiple against S&P 500: 0.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MOS; Returns Multiple against S&P 500: 1.15
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MPC; Returns Multiple against S&P 500: 0.78
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MRK; Returns Multiple against S&P 500: 0.79
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MRO; Returns Multiple against S&P 500: 0.57
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MS; Returns Multiple against S&P 500: 1.17
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MSCI; Returns Multiple against S&P 500: 1.26
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MSFT; Returns Multiple against S&P 500: 1.15
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MSI; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MTB; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MTD; Returns Multiple against S&P 500: 1.35
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MU; Returns Multiple against S&P 500: 1.2
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MXIM; Returns Multiple against S&P 500: 1.24
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NCLH; Returns Multiple against S&P 500: 0.38
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NDAQ; Returns Multiple against S&P 500: 1.09
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NEE; Returns Multiple against S&P 500: 1.09
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NEM; Returns Multiple against S&P 500: 1.14
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NFLX; Returns Multiple against S&P 500: 1.3
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NI; Returns Multiple against S&P 500: 0.68
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NKE; Returns Multiple against S&P 500: 1.22
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NLOK; Returns Multiple against S&P 500: 1.08
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NLSN; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NOC; Returns Multiple against S&P 500: 0.73
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NOV; Returns Multiple against S&P 500: 0.55
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NOW; Returns Multiple against S&P 500: 1.49
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NRG; Returns Multiple against S&P 500: 0.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NSC; Returns Multiple against S&P 500: 1.02
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NTAP; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NTRS; Returns Multiple against S&P 500: 0.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NUE; Returns Multiple against S&P 500: 0.95
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NVDA; Returns Multiple against S&P 500: 1.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NVR; Returns Multiple against S&P 500: 1.01
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NWL; Returns Multiple against S&P 500: 1.18
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NWS; Returns Multiple against S&P 500: 1.17
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NWSA; Returns Multiple against S&P 500: 1.23
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: O; Returns Multiple against S&P 500: 0.7
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ODFL; Returns Multiple against S&P 500: 1.22
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: OKE; Returns Multiple against S&P 500: 0.54
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: OMC; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ORCL; Returns Multiple against S&P 500: 1.02
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ORLY; Returns Multiple against S&P 500: 0.98
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: OTIS; Returns Multiple against S&P 500: 1.22
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: OXY; Returns Multiple against S&P 500: 0.47
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PAYC; Returns Multiple against S&P 500: 1.27
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PAYX; Returns Multiple against S&P 500: 0.92
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PBCT; Returns Multiple against S&P 500: 0.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PCAR; Returns Multiple against S&P 500: 1.11
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PEAK; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PEG; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PEP; Returns Multiple against S&P 500: 0.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PFE; Returns Multiple against S&P 500: 0.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PFG; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PG; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PGR; Returns Multiple against S&P 500: 0.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PH; Returns Multiple against S&P 500: 1.12
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PHM; Returns Multiple against S&P 500: 0.91
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PKG; Returns Multiple against S&P 500: 1.13
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PKI; Returns Multiple against S&P 500: 1.29
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PLD; Returns Multiple against S&P 500: 1.01
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PM; Returns Multiple against S&P 500: 0.89
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PNC; Returns Multiple against S&P 500: 0.92
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PNR; Returns Multiple against S&P 500: 1.07
#
# ...
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: STT; Returns Multiple against S&P 500: 0.82
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: STX; Returns Multiple against S&P 500: 1.12
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: STZ; Returns Multiple against S&P 500: 0.98
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SWK; Returns Multiple against S&P 500: 0.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SWKS; Returns Multiple against S&P 500: 1.33
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SYF; Returns Multiple against S&P 500: 1.0
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SYK; Returns Multiple against S&P 500: 0.95
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SYY; Returns Multiple against S&P 500: 0.89
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: T; Returns Multiple against S&P 500: 0.7
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TAP; Returns Multiple against S&P 500: 0.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TDG; Returns Multiple against S&P 500: 0.83
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TDY; Returns Multiple against S&P 500: 0.88
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TEL; Returns Multiple against S&P 500: 1.2
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TER; Returns Multiple against S&P 500: 1.53
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TFC; Returns Multiple against S&P 500: 0.89
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TFX; Returns Multiple against S&P 500: 0.91
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TGT; Returns Multiple against S&P 500: 1.44
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TJX; Returns Multiple against S&P 500: 0.96
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TMO; Returns Multiple against S&P 500: 1.28
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TMUS; Returns Multiple against S&P 500: 1.36
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TPR; Returns Multiple against S&P 500: 1.09
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TRMB; Returns Multiple against S&P 500: 1.39
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TROW; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TRV; Returns Multiple against S&P 500: 0.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TSCO; Returns Multiple against S&P 500: 1.32
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TSLA; Returns Multiple against S&P 500: 4.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TSN; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TT; Returns Multiple against S&P 500: 1.19
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TTWO; Returns Multiple against S&P 500: 1.36
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TWTR; Returns Multiple against S&P 500: 1.27
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TXN; Returns Multiple against S&P 500: 1.15
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TXT; Returns Multiple against S&P 500: 0.81
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TYL; Returns Multiple against S&P 500: 1.1
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UA; Returns Multiple against S&P 500: 0.82
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UAA; Returns Multiple against S&P 500: 0.85
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UAL; Returns Multiple against S&P 500: 0.46
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UDR; Returns Multiple against S&P 500: 0.73
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UHS; Returns Multiple against S&P 500: 0.81
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ULTA; Returns Multiple against S&P 500: 0.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UNH; Returns Multiple against S&P 500: 0.99
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UNM; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UNP; Returns Multiple against S&P 500: 0.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UPS; Returns Multiple against S&P 500: 1.36
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: URI; Returns Multiple against S&P 500: 1.47
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: USB; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: V; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VAR; Returns Multiple against S&P 500: 1.07
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VFC; Returns Multiple against S&P 500: 0.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VIAC; Returns Multiple against S&P 500: 1.35
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VLO; Returns Multiple against S&P 500: 0.67
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VMC; Returns Multiple against S&P 500: 0.91
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VNO; Returns Multiple against S&P 500: 0.52
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VNT; Returns Multiple against S&P 500: 0.9
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VRSK; Returns Multiple against S&P 500: 0.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VRSN; Returns Multiple against S&P 500: 0.79
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VRTX; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VTR; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VTRS; Returns Multiple against S&P 500: 0.68
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: VZ; Returns Multiple against S&P 500: 0.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WAB; Returns Multiple against S&P 500: 0.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WAT; Returns Multiple against S&P 500: 1.12
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WBA; Returns Multiple against S&P 500: 0.83
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WDC; Returns Multiple against S&P 500: 0.76
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WEC; Returns Multiple against S&P 500: 0.77
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WELL; Returns Multiple against S&P 500: 0.68
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WFC; Returns Multiple against S&P 500: 0.61
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WHR; Returns Multiple against S&P 500: 1.1
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WLTW; Returns Multiple against S&P 500: 0.88
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WM; Returns Multiple against S&P 500: 0.8
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WMB; Returns Multiple against S&P 500: 0.96
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WMT; Returns Multiple against S&P 500: 1.08
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WRB; Returns Multiple against S&P 500: 0.73
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WRK; Returns Multiple against S&P 500: 0.89
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WST; Returns Multiple against S&P 500: 1.57
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WU; Returns Multiple against S&P 500: 0.74
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WY; Returns Multiple against S&P 500: 1.04
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WYNN; Returns Multiple against S&P 500: 0.71
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: XEL; Returns Multiple against S&P 500: 0.81
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: XLNX; Returns Multiple against S&P 500: 1.36
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: XOM; Returns Multiple against S&P 500: 0.73
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: XRAY; Returns Multiple against S&P 500: 0.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: XRX; Returns Multiple against S&P 500: 0.55
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: XYL; Returns Multiple against S&P 500: 1.02
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: YUM; Returns Multiple against S&P 500: 0.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ZBH; Returns Multiple against S&P 500: 0.88
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ZBRA; Returns Multiple against S&P 500: 1.4
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ZION; Returns Multiple against S&P 500: 0.92
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ZTS; Returns Multiple against S&P 500: 0.98
#
# A made the Minervini requirements
# AAPL made the Minervini requirements
# ABBV made the Minervini requirements
# ABMD made the Minervini requirements
# ABT made the Minervini requirements
# ADBE made the Minervini requirements
# ADI made the Minervini requirements
# ADSK made the Minervini requirements
# AES made the Minervini requirements
# ALGN made the Minervini requirements
# ALXN made the Minervini requirements
# AMAT made the Minervini requirements
# AMZN made the Minervini requirements
# ANET made the Minervini requirements
# ANSS made the Minervini requirements
# AOS made the Minervini requirements
# APTV made the Minervini requirements
# ATVI made the Minervini requirements
# AVGO made the Minervini requirements
# AVY made the Minervini requirements
# BBY made the Minervini requirements
# BIO made the Minervini requirements
# BLK made the Minervini requirements
# BWA made the Minervini requirements
# CAT made the Minervini requirements
# CDNS made the Minervini requirements
# CMG made the Minervini requirements
# CMI made the Minervini requirements
# CTLT made the Minervini requirements
# CTVA made the Minervini requirements
# DD made the Minervini requirements
# DE made the Minervini requirements
# DFS made the Minervini requirements
# DHI made the Minervini requirements
# DHR made the Minervini requirements
# DIS made the Minervini requirements
# DISCA made the Minervini requirements
# EA made the Minervini requirements
# EMN made the Minervini requirements
# ENPH made the Minervini requirements
# ETSY made the Minervini requirements
# EXPE made the Minervini requirements
# F made the Minervini requirements
# FBHS made the Minervini requirements
# FCX made the Minervini requirements
# FFIV made the Minervini requirements
# FRC made the Minervini requirements
# GLW made the Minervini requirements
# GM made the Minervini requirements
# GOOG made the Minervini requirements
# GOOGL made the Minervini requirements
# GS made the Minervini requirements
# HOLX made the Minervini requirements
# ICE made the Minervini requirements
# IDXX made the Minervini requirements
# ILMN made the Minervini requirements
# INTU made the Minervini requirements
# IPGP made the Minervini requirements
# IVZ made the Minervini requirements
# JBHT made the Minervini requirements
# JCI made the Minervini requirements
# KEYS made the Minervini requirements
# KLAC made the Minervini requirements
# KMX made the Minervini requirements
# KSU made the Minervini requirements
# LB made the Minervini requirements
# LEN made the Minervini requirements
# LLY made the Minervini requirements
# LOW made the Minervini requirements
# LRCX made the Minervini requirements
# MCHP made the Minervini requirements
# MKTX made the Minervini requirements
# MNST made the Minervini requirements
# MOS made the Minervini requirements
# MS made the Minervini requirements
# MSCI made the Minervini requirements
# MSFT made the Minervini requirements
# MTD made the Minervini requirements
# MU made the Minervini requirements
# MXIM made the Minervini requirements
# NDAQ made the Minervini requirements
# NEE made the Minervini requirements
# NFLX made the Minervini requirements
# NKE made the Minervini requirements
# NOW made the Minervini requirements
# NVDA made the Minervini requirements
# NWL made the Minervini requirements
# NWS made the Minervini requirements
# NWSA made the Minervini requirements
# ODFL made the Minervini requirements
# PAYC made the Minervini requirements
# PCAR made the Minervini requirements
# PNR made the Minervini requirements
# POOL made the Minervini requirements
# PWR made the Minervini requirements
# PYPL made the Minervini requirements
# SIVB made the Minervini requirements
# SNPS made the Minervini requirements
# STX made the Minervini requirements
# SWKS made the Minervini requirements
# TEL made the Minervini requirements
# TER made the Minervini requirements
# TGT made the Minervini requirements
# TMO made the Minervini requirements
# TPR made the Minervini requirements
# TRMB made the Minervini requirements
# TSCO made the Minervini requirements
# TSLA made the Minervini requirements
# TT made the Minervini requirements
# TTWO made the Minervini requirements
# TWTR made the Minervini requirements
# TXN made the Minervini requirements
# URI made the Minervini requirements
# VAR made the Minervini requirements
# VIAC made the Minervini requirements
# WAT made the Minervini requirements
# WST made the Minervini requirements
# ZBRA made the Minervini requirements
#
#      Stock RS_Rating  50 Day MA  ...  200 Day MA  52 Week Low  52 week High
# 40   ETSY       100     183.19  ...      128.21        29.95        226.73
# 39   ENPH       100     171.90  ...       97.20        21.49        222.43
# 107  TSLA       100     720.45  ...      415.49        70.10        900.40
# 44    FCX        99      26.71  ...       17.01         4.82         32.49
# 85   NVDA        99     530.70  ...      464.46       180.68        589.07
# ..    ...       ...        ...  ...         ...          ...           ...
# 51     GS        71     263.71  ...      215.06       130.85        309.41
# 92    PNR        70      53.75  ...       45.43        22.01         59.30
# 32    DFS        70      87.65  ...       62.23        23.25        100.96
# 113   VAR        70     175.00  ...      154.96        89.62        176.39
# 64    KSU        70     201.90  ...      174.21        92.86        223.59
#
# [118 rows x 7 columns]
